# %% [markdown]
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# create a figure object called fig using plt.figure()
#
# Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this as new axis ax.
#
# Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Title")
# Out:
# Text(0.5,1,'Title')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
newax=fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
newax=fig.add_axes([0.2,0.5,.2,.2])
newax.plot(x,y)
ax.plot(x,y)
newax.set_xlabel('x')
newax.set_ylabel('y')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0,0.5,'y')

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig=plt.figure(figsize=(18,10))
ax=fig.add_axes([0,0,1,1])
newax=fig.add_axes([0.2,0.5,.4,.4])

# %%
fig=plt.figure(figsize=(10,5))
ax=fig.add_axes([0,0,1,1])
newax=fig.add_axes([0.2,0.5,.4,.4])
newax.plot(x,y)
ax.plot(x,z)
ax.set_xlabel('X')
ax.set_ylabel('Z')
newax.set_title('zoom')
newax.set_xlabel('X')
newax.set_ylabel('Y')
newax.set_xlim(20.0,22.0)
newax.set_ylim(30,50)
# Out:
# (30, 50)

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
plt.subplots(nrows=1,ncols=2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000096172B0>,
# ...
#        dtype=object))

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=False)
ax1.plot(x, y,"b--",lw=4)
ax2.plot(y, z,'r',lw=4)

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=False,figsize=(18,5))
ax1.plot(x, y,"b",lw=4)
ax2.plot(y, z,'r--',lw=4)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax2.set_xlabel('Y')
ax2.set_ylabel('Z')
# Out:
# Text(0,0.5,'Z')
